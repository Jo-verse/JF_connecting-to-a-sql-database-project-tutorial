# %% [markdown]
# # **Listado de Actividades**

# %% [markdown]
# ## **Ejercicios de Nivel Básico: Primeros Pasos con Selenium**

# %% [markdown]
# ### 1. Abrir una página web y extraer el título
#
# *   Objetivo: Aprender a abrir una página web y extraer el título de la página

# %% [markdown]
# ### 2. Extraer todas las citas y autores de la página
#
# * Objetivo: Aprender a interactuar con los elementos de una página web y extraer información de ellos.

# %% [markdown]
# ## **Ejercicios de Nivel Intermedio: Interacción con Elementos y Páginas Dinámicas**

# %% [markdown]
# ### 3. Realizar una búsqueda en eBay y extraer los primeros 10 resultados
#
# * Objetivo: Simular una búsqueda en eBay y extraer información de los primeros 10 resultados de productos.

# %% [markdown]
# ### 4. Manejo de Páginas con Carga Dinámica (Scroll Automático)
#
# * Objetivo: Realizar scroll para cargar contenido dinámicamente y extraer información.

# %% [markdown]
# ## **Ejercicios de Nivel Avanzado: Técnicas Avanzadas y Evitar Detección de Bots**

# %% [markdown]
# ### 5. Simulación de inicio de sesión en un sitio web
#
# * Objetivo: Simularemos un inicio de sesión en un sitio web para entender cómo interactuar con formularios de inicio de sesión.

# %% [markdown]
# ### 6. Extracción de Datos de una Tabla con Selenium
#
# * Objetivo: Automatizar la extracción de información desde una tabla de datos en una página web de pruebas y guardarla en un archivo CSV.
